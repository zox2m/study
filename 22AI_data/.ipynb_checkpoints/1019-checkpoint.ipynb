# %%
import pandas as pd

df = pd.read_csv('./auto-mpg.csv',header=None)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15080\3223822164.py in <module>
#       2
#       3 df = pd.read_csv('./auto-mpg.csv',header=None)
# ----> 4 df=df.astype(float)
#       5 df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
# ...

# %%
df.columns = ['mpg','cylinders','difplacement','horsepower','weight','acceleration ','model year','origin','name']

# %%
print(df.head())
print('\n')
print(df.tail())
# Out:
#     mpg  cylinders  difplacement horsepower  weight  acceleration   \
# 0  18.0          8         307.0      130.0  3504.0           12.0
# 1  15.0          8         350.0      165.0  3693.0           11.5
# 2  18.0          8         318.0      150.0  3436.0           11.0
# 3  16.0          8         304.0      150.0  3433.0           12.0
# 4  17.0          8         302.0      140.0  3449.0           10.5
#
#    model year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino
#
#
#       mpg  cylinders  difplacement horsepower  weight  acceleration   \
# 393  27.0          4         140.0      86.00  2790.0           15.6
# 394  44.0          4          97.0      52.00  2130.0           24.6
# ...

# %%
print(df.shape)
print(df.info())
# Out:
# (398, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mpg            398 non-null    float64
#  1   cylinders      398 non-null    int64
#  2   difplacement   398 non-null    float64
#  3   horsepower     398 non-null    object
#  4   weight         398 non-null    float64
#  5   acceleration   398 non-null    float64
#  6   model year     398 non-null    int64
#  7   origin         398 non-null    int64
#  8   name           398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# None

# %%
#데이터프레임 df의 자료형 확인
print(df.dtypes)
#시지르(mpg열)의 자료형 확인
print(df.mpg.dtypes)
# Out:
# mpg              float64
# cylinders          int64
# difplacement     float64
# horsepower        object
# weight           float64
# acceleration     float64
# model year         int64
# origin             int64
# name              object
# dtype: object
# float64

# %%
#데이터프레임 df의 기술통꼐정보확인
print(df.describe())
print('\n')
print(df.describe(include='all'))
# Out:
#               mpg   cylinders  difplacement       weight  acceleration   \
# count  398.000000  398.000000    398.000000   398.000000     398.000000
# mean    23.514573    5.454774    193.425879  2970.424623      15.568090
# std      7.815984    1.701004    104.269838   846.841774       2.757689
# min      9.000000    3.000000     68.000000  1613.000000       8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000      13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000      15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000      17.175000
# max     46.600000    8.000000    455.000000  5140.000000      24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000
#
#
# ...

# %%
df.count()
type(df.count())
# Out:
# pandas.core.series.Series

# %%
#df의 특정 열이 가지고있는고유값 확인
unique_values = df['origin'].value_counts()
unique_values
type(unique_values)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #통계함수 적용

# %%
df.mean()
# Out:
# C:\Users\jumin\AppData\Local\Temp\ipykernel_15080\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# mpg                23.514573
# cylinders           5.454774
# difplacement      193.425879
# weight           2970.424623
# acceleration       15.568090
# model year         76.010050
# origin              1.572864
# dtype: float64

# %%
df['mpg'].mean()
df.mpg.mean()
df[['mpg','weight']].mean()
# Out:
# mpg         23.514573
# weight    2970.424623
# dtype: float64

# %%
# 최대값
df.max()
df['mpg'].max()
# Out:
# 46.6

# %%
#최소값
df.min()
df['mpg'].min()
# Out:
# 9.0

# %%
#표준편차
df.std()
df['mpg'].std()
# Out:
# C:\Users\jumin\AppData\Local\Temp\ipykernel_15080\3181050538.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# 7.815984312565782

# %%
#상관계수
df.corr()
df[['mpg','weight']].corr()
# Out:
#              mpg    weight
# mpg     1.000000 -0.831741
# weight -0.831741  1.000000

# %% [markdown]
# #내장 그래프 도구

# %%
df= pd.read_excel('./남북한발전전력량.xlsx')

df_ns =df.iloc[[0,5],3:]
df_ns.index = ['South','North']
df_ns.columns = df_ns.columns.map(int)
df_ns.head()
# Out:
#        1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# South  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# North   263   247   221   231   230   213   193   170   186   194  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %%
#선 그래프 그리기 우와~ 신기하다 
df_ns.plot()
# Out:
# <AxesSubplot:>

# %%
#전치하기
tdf_ns = df_ns.T
tdf_ns.head()
tdf_ns.plot()
# Out:
# <AxesSubplot:>

# %%
#막대그래프
tdf_ns.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#누적 막대그래프 
tdf_ns.plot(kind='bar',color=['#209FDF','#99CA53'],stacked=True)
#가로막대
tdf_ns.plot(kind='barh')
tdf_ns.plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot:>

# %%
#히스토그램

tdf_ns=tdf_ns.astype(float)
tdf_ns.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#산점도

#read_csv()로 df 생성
df=pd.read_csv('auto-mpg.csv')

#열 이름 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight','acceleration','model','origin','name']
df.plot(x='weight',y='mpg',kind='scatter')
#색 바꾸기
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
#박스플롯
df.plot(kind='box',y=['mpg','cylinders'])
#색바꾸기
# Out:
# <AxesSubplot:>
